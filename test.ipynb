# %%
from ase.io import read, write
from ase.io.lammpsdata import write_lammps_data

atoms = read("out/Ih/out_10_H.data", format="lammps-data")

print(atoms)

bonds = atoms.arrays['bonds']
angles = atoms.arrays['angles']

print(bonds)
print(angles)

print(list(atoms.arrays.keys()))

print(atoms)
atoms.get_celldisp()
# Out:
# Atoms(symbols='H4342O2171', pbc=True, cell=[160.0, 160.0, 112.5], angles=..., bonds=..., id=..., initial_charges=..., masses=..., mmcharges=..., mol-id=..., type=...)
# ['1(1),2(1)' '_' '_' ... '6511(1),6512(1)' '_' '_']
# ['1-2(1)' '_' '_' ... '6511-6512(1)' '_' '_']
# ['numbers', 'positions', 'masses', 'id', 'type', 'mol-id', 'initial_charges', 'mmcharges', 'bonds', 'angles']
# Atoms(symbols='H4342O2171', pbc=True, cell=[160.0, 160.0, 112.5], angles=..., bonds=..., id=..., initial_charges=..., masses=..., mmcharges=..., mol-id=..., type=...)
# array([[0.],
#        [0.],
#        [0.]])
